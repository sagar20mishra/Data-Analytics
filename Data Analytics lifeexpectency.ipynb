# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
df=pd.read_csv('F:/Life Expectancy Data.csv')

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
print(df.groupby('Year')['Life expectancy '].mean())
# Out:
# Year
# 2000    66.750273
# 2001    67.128962
# 2002    67.351366
# 2003    67.433333
# 2004    67.646448
# 2005    68.209290
# 2006    68.667760
# 2007    69.036066
# 2008    69.427869
# 2009    69.938251
# 2010    70.048634
# 2011    70.654098
# 2012    70.916940
# 2013    71.236066
# 2014    71.536612
# 2015    71.616940
# Name: Life expectancy , dtype: float64

# %%
groups=df.groupby(['Year','Status'])[['Life expectancy ','GDP']].mean()

# %%
groups
# Out:
#                  Life expectancy            GDP
# Year Status
# 2000 Developed          76.803125  15215.825425
#      Developing         64.619868   2373.557362
# 2001 Developed          77.128125  16036.874398
#      Developing         65.009934   2389.128353
# 2002 Developed          77.546875  13724.055247
#      Developing         65.190728   2587.546652
# 2003 Developed          77.940625  12449.282651
#      Developing         65.206623   3082.831620
# 2004 Developed          78.384375  22409.726689
#      Developing         65.370861   3697.237869
# 2005 Developed          78.590625  22138.289277
#      Developing         66.009272   3992.927805
# 2006 Developed          79.131250  25701.090716
#      Developing         66.450331   3332.083049
# 2007 Developed          79.300000  28307.900841
#      Developing         66.860927   4212.411736
# 2008 Developed          78.931250  34141.452187
#      Developing         67.413907   5455.231527
# ...

# %%
flat=groups.reset_index()

# %%
flat
# Out:
#     Year      Status  Life expectancy            GDP
# 0   2000   Developed         76.803125  15215.825425
# 1   2000  Developing         64.619868   2373.557362
# 2   2001   Developed         77.128125  16036.874398
# 3   2001  Developing         65.009934   2389.128353
# 4   2002   Developed         77.546875  13724.055247
# 5   2002  Developing         65.190728   2587.546652
# 6   2003   Developed         77.940625  12449.282651
# 7   2003  Developing         65.206623   3082.831620
# 8   2004   Developed         78.384375  22409.726689
# 9   2004  Developing         65.370861   3697.237869
# 10  2005   Developed         78.590625  22138.289277
# 11  2005  Developing         66.009272   3992.927805
# 12  2006   Developed         79.131250  25701.090716
# 13  2006  Developing         66.450331   3332.083049
# 14  2007   Developed         79.300000  28307.900841
# 15  2007  Developing         66.860927   4212.411736
# 16  2008   Developed         78.931250  34141.452187
# ...

# %%
print(flat.head(10))
# Out:
#    Year      Status  Life expectancy            GDP
# 0  2000   Developed         76.803125  15215.825425
# 1  2000  Developing         64.619868   2373.557362
# 2  2001   Developed         77.128125  16036.874398
# 3  2001  Developing         65.009934   2389.128353
# 4  2002   Developed         77.546875  13724.055247
# 5  2002  Developing         65.190728   2587.546652
# 6  2003   Developed         77.940625  12449.282651
# 7  2003  Developing         65.206623   3082.831620
# 8  2004   Developed         78.384375  22409.726689
# 9  2004  Developing         65.370861   3697.237869

# %%
s_range=list(range(5))
print(s_range)
# Out:
# [0, 1, 2, 3, 4]

# %%
flap=df.iloc[:,s_range]   #subsetting rows using iloc and list

# %%
print(flap.head())
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0

# %%
print(df.loc[42,'Country'])  #subsetting rows and columsn using
# Out:
# Algeria

# %%
print(df.iloc[42,0])   #subsetting rows and columns using iloc
# Out:
# Algeria

# %%
print(df.iloc[[0,42,90],[0,2,4]]) #subsetting multiple  rows and columns both using iloc simultaneously
# Out:
#         Country      Status  Adult Mortality
# 0   Afghanistan  Developing            263.0
# 42      Algeria  Developing            136.0
# 90    Argentina  Developing            127.0

# %%
print(df.loc[[0,42,90],['Country','Status','Adult Mortality']]) #subsetting multiple rows an columns using loc
# Out:
#         Country      Status  Adult Mortality
# 0   Afghanistan  Developing            263.0
# 42      Algeria  Developing            136.0
# 90    Argentina  Developing            127.0

# %%
print(df.loc[0:5,['Country','Status','Adult Mortality']])  #subsetting multiple rows and columns in sequence using loc
# Out:
#        Country      Status  Adult Mortality
# 0  Afghanistan  Developing            263.0
# 1  Afghanistan  Developing            271.0
# 2  Afghanistan  Developing            268.0
# 3  Afghanistan  Developing            272.0
# 4  Afghanistan  Developing            275.0
# 5  Afghanistan  Developing            279.0

# %%
print(df.groupby('Status')['Country'].nunique())
# Out:
# Status
# Developed      32
# Developing    161
# Name: Country, dtype: int64

# %%
g_y_life=df.groupby('Year')['Life expectancy '].mean()

# %%
print(g_y_life)
# Out:
# Year
# 2000    66.750273
# 2001    67.128962
# 2002    67.351366
# 2003    67.433333
# 2004    67.646448
# 2005    68.209290
# 2006    68.667760
# 2007    69.036066
# 2008    69.427869
# 2009    69.938251
# 2010    70.048634
# 2011    70.654098
# 2012    70.916940
# 2013    71.236066
# 2014    71.536612
# 2015    71.616940
# Name: Life expectancy , dtype: float64

# %%
g_y_life.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#visual Reprsentation of data

# %%
flap.plot()
# Out:
# <AxesSubplot:>
